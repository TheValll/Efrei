# %% [markdown]
# # 2.4 Exercice 4 — Deep Learning : erreurs + saliency (MNIST)
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %% [markdown]
# TODO: CNN MNIST léger + erreurs + saliency map.

# %%
# TODO
