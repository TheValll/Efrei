# %% [markdown]
# # Capstone — Détection de fraude : du brut à la communication
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %%
raw_path = DATA_DIR/'capstone'/'fraud_transactions_raw.csv'
df = pd.read_csv(raw_path)
df.head()

# %% [markdown]
# TODO: nettoyage + préparation + modèle(s) + PR-AUC + rapport.

# %%
# TODO
