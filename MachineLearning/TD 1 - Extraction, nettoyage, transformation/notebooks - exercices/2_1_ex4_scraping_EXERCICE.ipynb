# %% [markdown]
# # 2.1 Exercice 4 — Web scraping éthique (site local + robots.txt)
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %%
site_dir = DATA_DIR/'2_1_extraction'/'ex4_scraping_local_site'

# %% [markdown]
# TODO: lire robots.txt, scraper pages autorisées, pagination via a.next, export catalog.csv.

# %%
# TODO
