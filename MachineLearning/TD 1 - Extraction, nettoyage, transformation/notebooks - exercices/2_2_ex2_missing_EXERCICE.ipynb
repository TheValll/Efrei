# %% [markdown]
# # 2.2 Exercice 2 — Valeurs manquantes : stratégies comparées
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %%
df = pd.read_csv(DATA_DIR/'2_2_cleaning'/'customers_dirty.csv')

# %% [markdown]
# TODO: créer cible, pipelines Simple/KNN/Iterative, comparer ROC-AUC.

# %%
# TODO
