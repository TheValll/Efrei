# %% [markdown]
# # 2.3 Exercice 5 — Feature engineering temporel (logs -> features)
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %%
events = pd.read_csv(DATA_DIR/'2_3_transformation'/'event_logs'/'events.csv')
events.head()

# %%
# TODO: features 7j + split temporel
