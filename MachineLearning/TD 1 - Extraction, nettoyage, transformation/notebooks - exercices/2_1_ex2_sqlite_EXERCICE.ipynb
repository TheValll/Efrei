# %% [markdown]
# # 2.1 Exercice 2 — Extraction SQL (SQLite) features RFM
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %%
db_path = DATA_DIR/'2_1_extraction'/'ex2_sqlite'/'retail.sqlite'

# %% [markdown]
# TODO: explorer schéma, requête paramétrée, features RFM + canaux, export.

# %%
# TODO
