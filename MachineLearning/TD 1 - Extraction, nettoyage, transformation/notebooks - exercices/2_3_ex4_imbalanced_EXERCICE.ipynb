# %% [markdown]
# # 2.3 Exercice 4 — Données déséquilibrées : under/over/SMOTE + métriques
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %%
df = pd.read_csv(DATA_DIR/'2_3_transformation'/'churn.csv')

# %%
# TODO: imblearn pipelines + PR-AUC + recall@precision>=0.8
