# %% [markdown]
# # 2.1 Exercice 1 — Ingestion robuste (CSV/JSON)
#
# Notebook d'exercice (sans réponses).

# %% [markdown]
# ## Setup
#
# Installe les dépendances si besoin (en environnement local).

# %%
import os, json, sqlite3, re, time
from pathlib import Path
import numpy as np
import pandas as pd

DATA_DIR = Path("../data")

# %% [markdown]
# Objectif : dataset unique typé + export Parquet (`customers_gold.parquet`).

# %%
input_dir = DATA_DIR/'2_1_extraction'/'ex1_flat_files'
files = sorted(input_dir.glob('customers_part_*.csv'))
files

# %%
# TODO: lecture robuste, harmonisation schéma, parsing dates, updates JSON, export
